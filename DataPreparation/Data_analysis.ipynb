# %% [markdown]
# ## Data Analysis

# %%
import os
import requests
import numpy as np
import netCDF4
import netCDF4 as nc
import pandas as pd
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
# import rioxarray # for 'rio' accessor
import xarray

# %% [markdown]
# The netcdf dataset was downloaded from https://data.ceda.ac.uk/badc/ukcp18/data/land-rcm/uk/12km/rcp85/01
# for the weather variables huss,tasmin,tasmax,rls,rss,pr,psl,uas,vas

# %%
humi = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\huss_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')

# %%
# projection_x_coordinate.units
huss = humi["huss"]
huss["projection_y_coordinate"].units
# Out:
# 'm'

# %%
huss["projection_x_coordinate"].units
# Out:
# 'm'

# %%
hum = humi['huss']

p = hum.isel(time=500).plot(
    subplot_kws =dict(projection=ccrs.epsg(7405), facecolor="gray"),
    transform=ccrs.epsg(7405))



# plt.title("Minimum air temperature")
p.axes.set_global()

p.axes.coastlines()

# %%
humi.data_vars
# Out:
# Data variables:
#     huss                          (ensemble_member, time, projection_y_coordinate, projection_x_coordinate) float32 ...
#     transverse_mercator           int32 ...
#     time_bnds                     (time, bnds) object ...
#     projection_y_coordinate_bnds  (projection_y_coordinate, bnds) float64 ...
#     projection_x_coordinate_bnds  (projection_x_coordinate, bnds) float64 ...

# %%
hum = humi['huss'][:]
hum
# Out:
# <xarray.DataArray 'huss' (ensemble_member: 1, time: 3600,
#                           projection_y_coordinate: 112,
#                           projection_x_coordinate: 82)>
# [33062400 values with dtype=float32]
# Coordinates:
#   * ensemble_member          (ensemble_member) int32 1
#   * time                     (time) object 2040-12-01 12:00:00 ... 2050-11-30...
#   * projection_y_coordinate  (projection_y_coordinate) float64 -1.02e+05 ... ...
#   * projection_x_coordinate  (projection_x_coordinate) float64 -2.1e+05 ... 7...
#     ensemble_member_id       (ensemble_member) |S27 ...
#     month_number             (time) int32 ...
#     year                     (time) int32 ...
#     yyyymmdd                 (time) |S64 ...
#     grid_longitude           (projection_y_coordinate, projection_x_coordinate) float64 ...
#     grid_latitude            (projection_y_coordinate, projection_x_coordinate) float64 ...
# Attributes:
#     standard_name:  specific_humidity
# ...

# %%
pr = humi["huss"][:]
pr = pr.isel(time=2000)
pr.plot()

# %%
shortwave = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\rss_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')

# %%
sv = shortwave['rss']

p = sv.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50 ), facecolor="gray"),
    transform=ccrs.epsg(7405),
)

# plt.title("Minimum air temperature")
p.axes.set_global()

p.axes.coastlines()

# %%
sv = shortwave['rss']

p = sv.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50 ), facecolor="white"),
    transform=ccrs.epsg(7405),
)

# plt.title("Minimum air temperature")
p.axes.set_global()

p.axes.coastlines()

# %%
sv = shortwave['rss']

p = sv.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.epsg(7405), facecolor="gray"),
    transform=ccrs.epsg(7405),
)

# plt.title("Minimum air temperature")
p.axes.set_global()

p.axes.coastlines()

# %%
longwave = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\rls_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')
lv = longwave['rls']

p = lv.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50), facecolor="white"),
    transform=ccrs.epsg(7405),
)

plt.title("Longwave flux")
p.axes.set_global()

p.axes.coastlines()

# %%
pe = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\pr_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')
precip = pe['pr']

p = precip.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50), facecolor="white"),
    transform=ccrs.epsg(7405),
)

plt.title("Precipitation rate")
p.axes.set_global()

p.axes.coastlines()

# %%
tmin = min['tasmin']

p = tmin.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50 ), facecolor="white"),
    transform=ccrs.epsg(7405),
)
plt.title("Minimum temperature")
p.axes.set_global()

p.axes.coastlines()

# %%
min = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\tasmin_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')
# lw = min['tasmin'][:]
# lw = lw.isel(time=1000)
# lw.plot()

# %%
max = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\tasmax_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')
tmax = max['tasmax']

p = tmax.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50 ), facecolor="white"),
    transform=ccrs.epsg(7405),
)
plt.title("Maximum temperature")
p.axes.set_global()

p.axes.coastlines()

# %%
v = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\vas_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')
north = v['vas']

p = north.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50 ), facecolor="white"),
    transform=ccrs.epsg(7405),
)
plt.title("Northward wind component")
p.axes.set_global()

p.axes.coastlines()

# %%
u = xr.open_dataset('C:\\Users\\Deepika Chandrababu\\Desktop\\uk_dataset\\uas_rcp85_land-rcm_uk_12km_01_day_20401201-20501130.nc')
east = u['uas']

p = east.isel(time=500).plot(
    subplot_kws=dict(projection=ccrs.Orthographic(-5,50 ), facecolor="white"),
    transform=ccrs.epsg(7405),
)
plt.title("Eastward wind component")
p.axes.set_global()

p.axes.coastlines()
